# %% [markdown]
# #  **Computer Vision and Pattern Recognition MidTerm Project**
# **Jui, Mahfuza Sharmili**
#
#  **ID: 19-39398-1**
#
# ### A machine learning algorithm has been implemented in order to classify different images of different objects. CIFAR-10 dataset has been used for this. I have computed the distance using Euclidian method. KNN algorithm has been used for this classificiation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.cifar10.load_data()
print(X_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
accuracy = []

for k in range(1, 21):
  print("k: ", k)
  acc = []
  for f in range(5):
    # divide data into folds
    validationX, validationY = X_train[f*10000:(f+1)*10000], Y_train[f*10000:(f+1)*10000]
    trainX = np.concatenate((X_train[:f*10000], X_train[(f+1)*10000:]), axis = 0)
    trainY = np.concatenate((Y_train[:f*10000], Y_train[(f+1)*10000:]), axis = 0)
    cm = ce = 0         # c for correct, m for manhattan, e for euclidean

    for i in range(len(validationX)):
      man_distance = []
      euc_distance = []

      for j in range(len(trainX)):
        
        # manhattan - calculating distance between two images
        l1 = np.sum(np.absolute(np.subtract(validationX[i], trainX[j])))

        # euclidean - calculation distance between two images
        l2 = np.sqrt(np.sum((validationX[i] - trainX[j])**2))

        man_distance.append([l1, trainY[j][0]])
        euc_distance.append([l2, trainY[j][0]])
        
        if j == 400:
            break

      man_distance = np.array(man_distance)
      man_distance = man_distance[man_distance[:, 0].argsort()]
      euc_distance = np.array(euc_distance)
      euc_distance = euc_distance[euc_distance[:, 0].argsort()]
      
      # for manhattan distance
      values = man_distance[:k, 1]

      # print(values)
      most_frequent_value = np.argmax(np.bincount(values.astype('int32')))

      # print(most_frequent_value)
      if most_frequent_value == validationY[i]:
        cm += 1
        
      # for euclidean distance
      values = euc_distance[:k, 1]
      most_frequent_value = np.argmax(np.bincount(values.astype('int32')))
      if most_frequent_value == validationY[i]:
        ce += 1


      if i == 120:
        break

    acc.append([cm, ce])
  accuracy.append([acc, k])

print(accuracy)
# Out:
# k:  1
# k:  2
# k:  3
# k:  4
# k:  5
# k:  6
# k:  7
# k:  8
# k:  9
# k:  10
# k:  11
# k:  12
# k:  13
# k:  14
# k:  15
# k:  16
# k:  17
# k:  18
# k:  19
# k:  20
# ...

# %%
avg1 = []
avg2 = []
k = np.array(accuracy)[:,1]

plt.figure(figsize=(20,5))


plt.subplot(1,2,2)
plt.title('Cross-Validation on K')
for i in range(len(accuracy)):
  a = np.full((5), i+1, dtype=int)
  l2 = np.array(accuracy[i][0])[:,1]
  avg2.append(np.average(l2))
  plt.plot(a, l2, 'o-')

plt.plot(k, avg2, 'o-')
plt.xlabel('k')
plt.ylabel('cross-validation accuracy')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # **Result**

# %% [markdown]
# ## The highest accuracy was about 28%

# %% [markdown]
# Cross validation has been used to estimate how the model is expected to perform in general when used to make predictions on data not used during the training of the model. The parameter K is used to refer to the number of groups
# the data sample is split into. I have taken K=5 to divide the dataset into 5 equal parts and the same process will be running for 5 times for each time.
# The value of K is chosen to train or test group of large data samples to statistically represent the larger dataset and get a accurate result when the overlapping or overfitting of the dataset is involved.

# %% [markdown]
# **What is KNN?**

# %% [markdown]
# K-nearest neighbors (KNN) algorithm is a type of supervised ML algorithm which can be used for both classification as well as regression predictive problems.K-NN algorithm stores all the available data and classifies a new data point based on the similarity. This means when new data appears then it can be easily classified into a well suite category by using K- NN algorithm.

# %% [markdown]
# **Where is KNN applied?**

# %% [markdown]
# KNN can be used for both classification and regression predictive problems. However, it is more widely used in classification problems. KNN is mostly used because of the ease to interpret output, faster calculation time and
# predictive Power

# %% [markdown]
# **Is KNN a good choice or bad choice for image classfication?**

# %% [markdown]
# KNN is a bad choice for image classification. As we can see in the plotted graph, that after using the KNN algorithm for image classification, the accuracy was only 28%. So, it is clearly not reliable enough for classifying images. While KNN is not reliable for classifying images, Neural Network is a good choice for image classification because with various neurons, it can detect and classify images more accurately.
# ![Screenshot-2020-10-12-at-10 (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **In which point did you get the highest accuracy?**

# %% [markdown]
# The accuracy was highest when the value of K was around 4 which is 28%, but the accuracy was stable when the value of K was around 11 to 12 which was 22% accuracy for 12, then it started declining as the values of K was higher towards 20. The accuracy is not much reliable for image classification while using KNN algorithm because of the inconsistency and less accurate classifications.
